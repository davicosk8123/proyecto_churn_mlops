# %% [markdown]
# # Exploración y Entrenamiento de Modelo Churn MLOps
#
# Este notebook se utiliza para la exploración inicial del dataset de clientes y para entrenar los modelos prototipo.

# %%
import pandas as pd
import numpy as np

# 1. Cargar datos
try:
    df = pd.read_csv('../data/data.csv')
    print("Datos cargados exitosamente. Vista previa:")
    print(df.head())
except FileNotFoundError:
    print("Error: No se encontró data.csv. Corre src/preparar_datos.py primero.")
